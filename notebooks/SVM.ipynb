# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn import svm
import pandas as pd
from sklearn import metrics

# %%
dataset = pd.read_csv('/content/X_test.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-e71ea78f9e01> in <module>()
# ----> 1 dataset = pd.read_csv('/content/X_test.csv')
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dataset.head(10)
# Out:
#     SK_ID_CURR  ...  ORGANIZATION_TYPE_XNA
# 0       347421  ...                      0
# 1       348357  ...                      0
# 2       418353  ...                      0
# 3       360057  ...                      1
# 4       301695  ...                      0
# 5       430682  ...                      0
# 6       123325  ...                      0
# 7       239959  ...                      0
# 8       378598  ...                      0
# 9       279545  ...                      0
# 10      324665  ...                      1
# 11      155915  ...                      0
# 12      451804  ...                      0
# 13      177004  ...                      0
# 14      407466  ...                      0
# 15      156462  ...                      0
# 16      224321  ...                      0
# 17      190583  ...                      1
# 18      103533  ...                      0
# 19      113072  ...                      0
# 20      433178  ...                      0
# ...

# %%
tabela = dataset.loc[:, [
    'AMT_INCOME_TOTAL', 
    'AMT_CREDIT'
  ]]
tabela.head()
# Out:
#    AMT_INCOME_TOTAL  AMT_CREDIT
# 0          0.228706    0.758415
# 1          0.231255    0.707582
# 2          0.197110    0.341120
# 3          0.122502    0.357668
# 4          0.175471    0.656304

# %%
A = tabela.AMT_INCOME_TOTAL
B = tabela.AMT_CREDIT

# %%
#Relação de Renda total com Credito
import matplotlib.pyplot as plt
import numpy as np

plt.scatter( dataset['AMT_INCOME_TOTAL'],dataset['AMT_CREDIT'], color ='r' )
plt.scatter( dataset['AMT_CREDIT'],dataset['AMT_INCOME_TOTAL'], color ='b')
plt.xlabel("AMT_INCOME_TOTAL")
plt.ylabel("AMT_CREDIT");
plt.show()

# %%
import plotly.graph_objects as go

categories = ['Alta confiança','Entre média e alta','Média',
              'Entre média e baixa', 'Baixa confiança']

fig = go.Figure()

fig.add_trace(go.Scatterpolar(
      r=dataset['AMT_INCOME_TOTAL'],
      theta=categories,
      fill='toself',
      name='AMT_INCOME_TOTAL'
))
fig.add_trace(go.Scatterpolar(
      r=dataset['AMT_CREDIT'],
      theta=categories,
      fill='toself',
      name='AMT_CREDIT'
))

fig.update_layout(
  polar=dict(
    radialaxis=dict(
      visible=True,
      range=[0, 1]
    )),
  showlegend=False
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="515409e6-5baa-4c7f-96ef-af40479a2e41" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("515409e6-5baa-4c7f-96ef-af40479a2e41")) {
#                     Plotly.newPlot(
#                         '515409e6-5baa-4c7f-96ef-af40479a2e41',
# ...

# %%
#Tamanho da base
tabela.shape
# Out:
# (91863, 2)

# %%
X_train, X_test, y_train, Y_test = train_test_split(X_train, y_train,train_size=)

# %%
cls = svm.SVC(kernel="linear", max_iter=1000)
#print(y_test)  AMT_CREDIT, Length: 36746, dtype: float64
#print(X_train) 0e1
#print(X_test)  AMT_INCOME_TOTAL, Length: 36746, dtype: float64
#print(y_train) AMT_CREDIT, Length: 55117, dtype: float64

cls.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9ee3305f457d> in <module>()
# ----> 1 cls = svm.SVC(kernel="linear", max_iter=1000)
#       2 #print(y_test)  AMT_CREDIT, Length: 36746, dtype: float64
#       3 #print(X_train) 0e1
#       4 #print(X_test)  AMT_INCOME_TOTAL, Length: 36746, dtype: float64
#       5 #print(y_train) AMT_CREDIT, Length: 55117, dtype: float64
#
# NameError: name 'svm' is not defined

# %%
print("acuracy",metrics.accuracy_score(y_test,y_train ))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-c7de62378b41> in <module>()
# ----> 1 print("acuracy",metrics.accuracy_score(y_test,y_train ))
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     183
#     184     # Compute accuracy for each possible representation
# --> 185     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     186     check_consistent_length(y_true, y_pred, sample_weight)
#     187     if y_type.startswith('multilabel'):
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      78     y_pred : array or indicator matrix
#      79     """
# ---> 80     check_consistent_length(y_true, y_pred)
#      81     type_true = type_of_target(y_true)
# ...

# %%
print("precision",metrics.precision_score(y_test,y_pred = pred))
# Out:
# precision 0.3369673424790579

# %%
print("recall",metrics.recall_score(y_test,y_pred = pred))
# Out:
# recall 0.7643333149749408

# %%
print(metrics.classification_report(y_test,y_pred = pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.65      0.23      0.34     35429
#            1       0.34      0.76      0.47     18157
#
#     accuracy                           0.41     53586
#    macro avg       0.50      0.50      0.40     53586
# weighted avg       0.55      0.41      0.38     53586
